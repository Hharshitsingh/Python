# %%
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\HARSHIT SINGH\Code\Python\Projects\52.Movie_revenue/cost_revenue.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = pd.DataFrame(data, columns=['production_budget_usd'])
y = pd.DataFrame(data, columns= ['worldwide_gross_usd'])

# %%
plt.figure(figsize=(15,8))
plt.scatter(X,y, alpha=0.5)
plt.title('Film cost vs Global revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()

# %%
regreesion = LinearRegression()
regreesion.fit(X, y, sample_weight=None)
# Out:
# LinearRegression()

# %% [markdown]
# ## Slop Coefficient

# %%
regreesion.coef_
# Out:
# array([[3.11150918]])

# %%
#intercept
regreesion.intercept_
# Out:
# array([-7236192.72913963])

# %%
plt.figure(figsize=(15,8))
plt.scatter(X,y, alpha=0.5)
plt.plot(X, regreesion.predict(X), color = 'red', linewidth = 3)
plt.title('Film cost vs Global revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()

# %%
regreesion.score(X, y)
# Out:
# 0.5496485356985727
